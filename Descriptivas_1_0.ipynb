# %% [markdown]
# <a href="https://colab.research.google.com/github/angie693/Repositorio/blob/main/Descriptivas_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('diabetes.xlsx')

# %%
df.head()
# Out:
#    X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...  X13  X14  X15  X16  X17  X18  \
# 0   1   1   1  40   1   0   0   0   0    1  ...    0    5   18   15    1    0
# 1   0   0   0  25   1   0   0   1   0    0  ...    1    3    0    0    0    0
# 2   1   1   1  28   0   0   0   0   1    0  ...    1    5   30   30    1    0
# 3   1   0   1  27   0   0   0   1   1    1  ...    0    2    0    0    0    0
# 4   1   1   1  24   0   0   0   1   1    1  ...    0    2    3    0    0    0
#
#    X19  X20  X21  Diabetes_binary
# 0    9    4    3                0
# 1    7    6    1                0
# 2    9    4    8                0
# 3   11    3    6                0
# 4   11    5    4                0
#
# [5 rows x 22 columns]

# %%
categorical_columns = df.drop(columns=['X5', 'X14', 'X15', 'X16', 'Diabetes_binary'])

for column in categorical_columns:
    print("Frecuencia de valores únicos para la variable", column)
    print(df[column].value_counts())
    print()
# Out:
# Frecuencia de valores únicos para la variable X1
# X1
# 0    144851
# 1    108829
# Name: count, dtype: int64
#
# Frecuencia de valores únicos para la variable X2
# X2
# 0    146089
# 1    107591
# Name: count, dtype: int64
#
# Frecuencia de valores únicos para la variable X3
# X3
# 1    244210
# 0      9470
# Name: count, dtype: int64
#
# Frecuencia de valores únicos para la variable X4
# X4
# 27    24606
# 26    20562
# 24    19550
# 25    17146
# 28    16545
#       ...
# 85        1
# 91        1
# 86        1
# 90        1
# 78        1
# Name: count, Length: 84, dtype: int64
#
# Frecuencia de valores únicos para la variable X6
# X6
# 0    243388
# 1     10292
# Name: count, dtype: int64
#
# Frecuencia de valores únicos para la variable X7
# X7
# 0    229787
# 1     23893
# Name: count, dtype: int64
#
# Frecuencia de valores únicos para la variable X8
# X8
# 1    191920
# 0     61760
# Name: count, dtype: int64
#
# Frecuencia de valores únicos para la variable X9
# X9
# ...

# %%
#BMI
plt.figure(figsize=(10, 6))
plt.hist(df['X4'], bins=15, color='skyblue', edgecolor='black')
plt.title('Histograma de Indice de masa corporal')
plt.xlabel('Indice de masa corporal')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# Gráficos de barras de las variables binarias según nivel de clasificación

# %%
#HighBP
plt.figure(figsize=(10, 6))

# Gráfico de barras para la variable categórica 'HighBP' con valores encima de las barras
ax = sns.countplot(x='X1', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación')
plt.xlabel('Tensión arterial alta')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()

#Genero - Puntaje
plt.figure(figsize=(8, 4))

# Gráfico de barras para la variable categórica 'estu_genero' con valores encima de las barras
ax = sns.countplot(x='X1', hue='Diabetes_binary', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación por Tensión arterial')
plt.xlabel('Tensión arterial alta')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-6-fdd507c403b7>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='X1', data=df, palette='Set2')

# %%
#Colesterol
plt.figure(figsize=(10, 6))

# Gráfico de barras para la variable categórica 'HighCol' con valores encima de las barras
ax = sns.countplot(x='X2', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación')
plt.xlabel('Colesterol Alto')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()

#Genero - Puntaje
plt.figure(figsize=(8, 4))

# Gráfico de barras para la variable categórica 'estu_genero' con valores encima de las barras
ax = sns.countplot(x='X2', hue='Diabetes_binary', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación por Colesterol')
plt.xlabel('Colesterol Alto')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-5-124537eb09c7>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='X2', data=df, palette='Set2')

# %%
#Chequeo de Colesterol
plt.figure(figsize=(10, 6))

# Gráfico de barras para la variable categórica 'Colcheck' con valores encima de las barras
ax = sns.countplot(x='X3', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación')
plt.xlabel('Chequeo de colesterol en los ultimos 5 años')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()

#Genero - Puntaje
plt.figure(figsize=(8, 4))

# Gráfico de barras para la variable categórica 'estu_genero' con valores encima de las barras
ax = sns.countplot(x='X3', hue='Diabetes_binary', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación por Chequeo de colesterol')
plt.xlabel('Chequeo de colesterol en los últimos 5 años')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-7-6f38b4052c68>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='X3', data=df, palette='Set2')

# %%
#Fumador
plt.figure(figsize=(10, 6))

# Gráfico de barras para la variable categórica 'Smoke' con valores encima de las barras
ax = sns.countplot(x='X5', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación')
plt.xlabel('Fumador')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()

#Genero - Puntaje
plt.figure(figsize=(8, 4))

# Gráfico de barras para la variable categórica 'estu_genero' con valores encima de las barras
ax = sns.countplot(x='X5', hue='Diabetes_binary', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación por fumadores')
plt.xlabel('Fumadores')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-13-82a9d43b7961>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='X5', data=df, palette='Set2')

# %%
# Infarto
plt.figure(figsize=(10, 6))

# Gráfico de barras para la variable categórica 'Stroke' con valores encima de las barras
ax = sns.countplot(x='X6', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación')
plt.xlabel('Infarto')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()

#Genero - Puntaje
plt.figure(figsize=(8, 4))

# Gráfico de barras para la variable categórica 'estu_genero' con valores encima de las barras
ax = sns.countplot(x='X6', hue='Diabetes_binary', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación por infarto')
plt.xlabel('Infarto')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-14-daaf1e5e9f01>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='X6', data=df, palette='Set2')

# %%
# Enfermedad cardiaca
plt.figure(figsize=(10, 6))

# Gráfico de barras para la variable categórica 'Stroke' con valores encima de las barras
ax = sns.countplot(x='X7', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación')
plt.xlabel('Enfermedades cardiacas o ataque cardiaco')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()

#Genero - Puntaje
plt.figure(figsize=(8, 4))

# Gráfico de barras para la variable categórica 'estu_genero' con valores encima de las barras
ax = sns.countplot(x='X7', hue='Diabetes_binary', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación por enfermedades cardiacas')
plt.xlabel('Enfermedades cardiacas')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-15-bd58a530290f>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='X7', data=df, palette='Set2')

# %%
# Actividad fisica
plt.figure(figsize=(10, 6))

# Gráfico de barras para la variable categórica 'Stroke' con valores encima de las barras
ax = sns.countplot(x='X8', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación')
plt.xlabel('Actividad fisica')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()

#Genero - Puntaje
plt.figure(figsize=(8, 4))

# Gráfico de barras para la variable categórica 'estu_genero' con valores encima de las barras
ax = sns.countplot(x='X8', hue='Diabetes_binary', data=df, palette='Set2')

# Configurar título y etiquetas de los ejes
plt.title('Distribución de Clasificación por actividad fisica')
plt.xlabel('Enfermedades cardiacas')
plt.ylabel('Frecuencia')

# Lista para almacenar los valores únicos de la clasificación
valores_clasificacion = []

# Añadir etiquetas con las frecuencias encima de cada barra
for p in ax.patches:
    if p.get_height() not in valores_clasificacion:
        valores_clasificacion.append(p.get_height())
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-17-aff572d5ea49>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='X8', data=df, palette='Set2')
